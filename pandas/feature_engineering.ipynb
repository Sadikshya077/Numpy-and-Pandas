# %%
import pandas as pd

# %%
df=pd.read_csv('cleaned_hr.csv')
df.head()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi Wilson  K  10026          0                0         1
# 1  Ait Sidi Karthikeyan  10084          1                1         1
# 2      Akinkuolie Sarah  10196          1                1         0
# 3           AlagbeTrina  10088          1                1         0
# 4        Anderson Carol  10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert         22          LinkedIn          Exceeds
# 1      Simon Roup          4            Indeed      Fully Meets
# 2  Kissy Sullivan         20          LinkedIn      Fully Meets
# 3    Elijiah Gray         16            Indeed      Fully Meets
# 4  Webster Butler         39     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                 2019-01-17              0        1
# 1                 2016-02-24              0       17
# 2                 2012-05-15              0        3
# 3                 2019-01-03              0       15
# 4                 2016-02-01              0        2
#
# [5 rows x 36 columns]

# %%
def dateconverter(dataframe, *args):
    for col in args:
        dataframe[col]=pd.to_datetime(dataframe[col], format ='mixed')
    print('Datetime converted')

# %%
dateconverter(df,'DOB','DateofHire','DateofTermination','LastPerformanceReview_Date')
# Out:
# Datetime converted

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
#  13  State                       311 non-null    object
#  14  Zip                         311 non-null    int64
#  15  DOB                         311 non-null    datetime64[ns]
#  16  Gender                      311 non-null    object
#  17  MaritalDesc                 311 non-null    object
#  18  CitizenDesc                 311 non-null    object
#  19  HispanicLatino              311 non-null    object
#  20  RaceDesc                    311 non-null    object
#  21  DateofHire                  311 non-null    datetime64[ns]
#  22  DateofTermination           104 non-null    datetime64[ns]
#  23  TermReason                  311 non-null    object
#  24  EmploymentStatus            311 non-null    object
#  25  Department                  311 non-null    object
#  26  ManagerName                 311 non-null    object
#  27  ManagerID                   311 non-null    int64
#  28  RecruitmentSource           311 non-null    object
#  29  PerformanceScore            311 non-null    object
#  30  EngagementSurvey            311 non-null    float64
#  31  EmpSatisfaction             311 non-null    int64
#  32  SpecialProjectsCount        311 non-null    int64
#  33  LastPerformanceReview_Date  311 non-null    datetime64[ns]
#  34  DaysLateLast30              311 non-null    int64
#  35  Absences                    311 non-null    int64
# dtypes: datetime64[ns](4), float64(1), int64(17), object(14)
# memory usage: 87.6+ KB

# %% [markdown]
# ## Extract Year, Month, Day

# %%
# df['DateofHire']
'''
Date Number
----------------------
dt.year -> year
dt.month -> month
df.dat -> day

Date Name
----------------------
dt.day_name() -> Day Name
dt.month_name() -> Month Name
'''

# %%
df['Hire_year']=df['DateofHire'].dt.year
df['Hire_month']=df['DateofHire'].dt.month
df['Hire_day']=df['DateofHire'].dt.day

# %%
df['Hire_month_name']=df['DateofHire'].dt.month_name()
df['Hire_day_name']=df['DateofHire'].dt.day_name()

# %%
df.head()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi Wilson  K  10026          0                0         1
# 1  Ait Sidi Karthikeyan  10084          1                1         1
# 2      Akinkuolie Sarah  10196          1                1         0
# 3           AlagbeTrina  10088          1                1         0
# 4        Anderson Carol  10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    EmpSatisfaction  SpecialProjectsCount LastPerformanceReview_Date  \
# 0                5                     0                 2019-01-17
# 1                3                     6                 2016-02-24
# 2                3                     0                 2012-05-15
# 3                5                     0                 2019-01-03
# 4                4                     0                 2016-02-01
#
#   DaysLateLast30  Absences Hire_year Hire_month Hire_day Hire_month_name  \
# 0              0         1      2011          7        5            July
# 1              0        17      2015          3       30           March
# 2              0         3      2011          7        5            July
# 3              0        15      2008          1        7         January
# 4              0         2      2011          7       11            July
#
#   Hire_day_name
# 0       Tuesday
# 1        Monday
# 2       Tuesday
# 3        Monday
# 4        Monday
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Convert Continuous Date into Categorical Data

# %%
'''
0 - 5 -> Low Absences
6 - 10 -> Medium Absences
10 - high -> High Absences
'''

# %%
df['Absences'].unique()
# Out:
# array([ 1, 17,  3, 15,  2, 19,  4, 16, 12,  9,  7, 20,  8, 13,  5, 14,  6,
#        11, 10, 18], dtype=int64)

# %%
def absenceCategory(absence):
    if absence >=0 and absence<=5:
        return 'Low Absences'
    elif absence >5 and absence<=10:
        return 'Medium Absences'
    else:
        return 'High Absences'

# %%
df['Absence_label']=df['Absences'].apply(absenceCategory) # parameter.apply(function)

# %%
df.head()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi Wilson  K  10026          0                0         1
# 1  Ait Sidi Karthikeyan  10084          1                1         1
# 2      Akinkuolie Sarah  10196          1                1         0
# 3           AlagbeTrina  10088          1                1         0
# 4        Anderson Carol  10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    SpecialProjectsCount  LastPerformanceReview_Date DaysLateLast30 Absences  \
# 0                     0                  2019-01-17              0        1
# 1                     6                  2016-02-24              0       17
# 2                     0                  2012-05-15              0        3
# 3                     0                  2019-01-03              0       15
# 4                     0                  2016-02-01              0        2
#
#    Hire_year Hire_month Hire_day Hire_month_name Hire_day_name  Absence_label
# 0       2011          7        5            July       Tuesday   Low Absences
# 1       2015          3       30           March        Monday  High Absences
# 2       2011          7        5            July       Tuesday   Low Absences
# 3       2008          1        7         January        Monday  High Absences
# 4       2011          7       11            July        Monday   Low Absences
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Date Encoding

# %% [markdown]
# ### Manual Encoding

# %%
# Manual encoding is done for the data that can be compared
# high - medium - low
# (2,1,0)

# %%
data ={
    'Low Absences':0,
    'Medium Absences': 1,
    'High Absences': 2
}

# %%
df['Absence_id']= df['Absence_label'].map(data)

# %%
df.head()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi Wilson  K  10026          0                0         1
# 1  Ait Sidi Karthikeyan  10084          1                1         1
# 2      Akinkuolie Sarah  10196          1                1         0
# 3           AlagbeTrina  10088          1                1         0
# 4        Anderson Carol  10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    LastPerformanceReview_Date  DaysLateLast30 Absences Hire_year  Hire_month  \
# 0                  2019-01-17               0        1      2011           7
# 1                  2016-02-24               0       17      2015           3
# 2                  2012-05-15               0        3      2011           7
# 3                  2019-01-03               0       15      2008           1
# 4                  2016-02-01               0        2      2011           7
#
#   Hire_day Hire_month_name Hire_day_name  Absence_label Absence_id
# 0        5            July       Tuesday   Low Absences          0
# 1       30           March        Monday  High Absences          2
# 2        5            July       Tuesday   Low Absences          0
# 3        7         January        Monday  High Absences          2
# 4       11            July        Monday   Low Absences          0
#
# [5 rows x 43 columns]

# %%
def encodedata(dataframe, col_name, *args):
    encode_data={}
    for idx, val in enumerate(args):
        encode_data[val]=idx
    dataframe[f'{col_name}_id']=dataframe[col_name].map(encode_data)
    print(f'{col_name} data encoded.')

# %%
encodedata(df,'Absence_label','Low Absences','Medium Absences', 'High Absences')
# Out:
# Absence_label data encoded.

# %% [markdown]
# ## Split

# %%
df['Absence_label'].unique()
# split (find, number_of_columns=index, expand=True/False(default))
# Out:
# array(['Low Absences', 'High Absences', 'Medium Absences'], dtype=object)

# %%
df[['Col1','Col2']]=df['Absence_label'].str.split(' ',n=1,expand=True)

# %%
df
# Out:
#             Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0      Adinolfi Wilson  K  10026          0                0         1
# 1    Ait Sidi Karthikeyan  10084          1                1         1
# 2        Akinkuolie Sarah  10196          1                1         0
# 3             AlagbeTrina  10088          1                1         0
# 4          Anderson Carol  10069          0                2         0
# ..                    ...    ...        ...              ...       ...
# 306         Woodson Jason  10135          0                0         1
# 307      Ybarra Catherine  10301          0                0         0
# 308       Zamora Jennifer  10010          0                0         0
# 309            Zhou Julia  10043          0                0         0
# 310          Zima Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 3              1       5            3                       0   64991  ...
# 4              5       5            3                       0   50825  ...
# ..           ...     ...          ...                     ...     ...  ...
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#      Hire_year  Hire_month Hire_day Hire_month_name  Hire_day_name  \
# 0         2011           7        5            July        Tuesday
# 1         2015           3       30           March         Monday
# 2         2011           7        5            July        Tuesday
# 3         2008           1        7         January         Monday
# 4         2011           7       11            July         Monday
# ..         ...         ...      ...             ...            ...
# 306       2014           7        7            July         Monday
# 307       2008           9        2       September        Tuesday
# 308       2010           4       10           April       Saturday
# 309       2015           3       30           March         Monday
# 310       2014           9       29       September         Monday
#
#      Absence_label Absence_id Absence_label_id  Col1      Col2
# 0     Low Absences          0                0   Low  Absences
# 1    High Absences          2                2  High  Absences
# 2     Low Absences          0                0   Low  Absences
# 3    High Absences          2                2  High  Absences
# 4     Low Absences          0                0   Low  Absences
# ..             ...        ...              ...   ...       ...
# 306  High Absences          2                2  High  Absences
# 307   Low Absences          0                0   Low  Absences
# 308  High Absences          2                2  High  Absences
# 309  High Absences          2                2  High  Absences
# 310   Low Absences          0                0   Low  Absences
#
# [311 rows x 46 columns]

# %%
hr=pd.read_csv('Dataset/HR_Dataset Refresh.csv')

# %%
first_last = hr['Employee_Name'].str.split(',',n=1,expand=True)

# %%
first_middle = first_last[1].str.strip().str.split(" ",n=1,expand=True)

# %%
df['First Name']=first_middle[0]
df['Middle Name']=first_middle[1]
df['Last Name']=first_last[0]

# %%
df.head(22)
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0     Adinolfi Wilson  K  10026          0                0         1
# 1   Ait Sidi Karthikeyan  10084          1                1         1
# 2       Akinkuolie Sarah  10196          1                1         0
# 3            AlagbeTrina  10088          1                1         0
# 4         Anderson Carol  10069          0                2         0
# 5         Anderson Linda  10002          0                0         0
# 6         Andreola Colby  10194          0                0         0
# 7             Athwal Sam  10062          0                4         1
# 8        Bachiochi Linda  10114          0                0         0
# 9       Bacong Alejandro  10250          0                2         1
# 10     Baczenski Rachael  10252          1                1         0
# 11        Barbara Thomas  10242          1                1         1
# 12       Barbossa Hector  10012          0                2         1
# 13   Barone Francesco  A  10265          0                0         1
# 14          Barton Nader  10066          0                2         1
# 15          Bates Norman  10061          0                0         1
# 16         Beak Kimberly  10023          1                1         0
# 17     Beatrice Courtney  10055          0                0         0
# 18          Becker Renee  10245          0                0         0
# 19          Becker Scott  10277          0                0         1
# 20        Bernstein Sean  10046          0                0         1
# 21        Biden Lowan  M  10226          0                2         0
#
#     EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0             1       5            4                       0   62506  ...
# 1             5       3            3                       0  104437  ...
# 2             5       5            3                       0   64955  ...
# 3             1       5            3                       0   64991  ...
# 4             5       5            3                       0   50825  ...
# 5             1       5            4                       0   57568  ...
# 6             1       4            3                       0   95660  ...
# 7             1       5            3                       0   59365  ...
# 8             3       5            3                       1   47837  ...
# 9             1       3            3                       0   50178  ...
# 10            5       5            3                       1   54670  ...
# 11            5       5            3                       1   47211  ...
# 12            1       3            4                       1   92328  ...
# 13            1       5            3                       0   58709  ...
# 14            5       5            3                       0   52505  ...
# 15            4       5            3                       0   57834  ...
# 16            2       5            4                       0   70131  ...
# 17            1       5            3                       0   59026  ...
# 18            4       3            3                       0  110000  ...
# 19            3       5            3                       0   53250  ...
# 20            1       5            3                       0   51044  ...
# 21            1       5            3                       0   64919  ...
#
#     Hire_month_name  Hire_day_name    Absence_label Absence_id  \
# 0              July        Tuesday     Low Absences          0
# 1             March         Monday    High Absences          2
# 2              July        Tuesday     Low Absences          0
# 3           January         Monday    High Absences          2
# 4              July         Monday     Low Absences          0
# 5           January         Monday    High Absences          2
# 6          November         Monday    High Absences          2
# 7         September         Monday    High Absences          2
# 8              July         Monday     Low Absences          0
# 9           January         Monday    High Absences          2
# 10          January         Monday    High Absences          2
# 11            April         Monday    High Absences          2
# 12         November         Monday  Medium Absences          1
# 13         February         Monday  Medium Absences          1
# 14        September         Monday     Low Absences          0
# 15         February         Monday    High Absences          2
# 16             July       Thursday    High Absences          2
# 17            April         Monday    High Absences          2
# 18             July         Monday  Medium Absences          1
# 19             July         Monday    High Absences          2
# 20            April         Monday    High Absences          2
# 21           August         Monday     Low Absences          0
#
#     Absence_label_id    Col1      Col2   First Name Middle Name   Last Name
# 0                  0     Low  Absences       Wilson           K    Adinolfi
# 1                  2    High  Absences  Karthikeyan        None    Ait Sidi
# 2                  0     Low  Absences        Sarah        None  Akinkuolie
# 3                  2    High  Absences        Trina        None      Alagbe
# 4                  0     Low  Absences        Carol        None    Anderson
# 5                  2    High  Absences        Linda        None    Anderson
# 6                  2    High  Absences        Colby        None    Andreola
# 7                  2    High  Absences          Sam        None      Athwal
# 8                  0     Low  Absences        Linda        None   Bachiochi
# 9                  2    High  Absences    Alejandro        None      Bacong
# 10                 2    High  Absences      Rachael        None   Baczenski
# 11                 2    High  Absences       Thomas        None     Barbara
# 12                 1  Medium  Absences       Hector        None    Barbossa
# 13                 1  Medium  Absences    Francesco           A      Barone
# 14                 0     Low  Absences        Nader        None      Barton
# 15                 2    High  Absences       Norman        None       Bates
# 16                 2    High  Absences     Kimberly        None        Beak
# 17                 2    High  Absences     Courtney        None    Beatrice
# 18                 1  Medium  Absences        Renee        None      Becker
# 19                 2    High  Absences       Wilson           K    Adinolfi
# 20                 2    High  Absences  Karthikeyan        None    Ait Sidi
# 21                 0     Low  Absences        Sarah        None  Akinkuolie
#
# [22 rows x 49 columns]

# %%
df.to_csv('cleaned_hr.csv',index=False)
